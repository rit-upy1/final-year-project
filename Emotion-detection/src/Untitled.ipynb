# %%
URL = 'https://en.wikipedia.org/wiki/London'
import pandas as pd

# %%
dfs = pd.read_html(URL)

# %%
print(f'Total tables: {len(dfs)}')
# Out:
# Total tables: 32

# %%
d=dfs[2]
d
# Out:
#                                London, United Kingdom  \
#                           Climate chart (explanation)
# 0   J F M A M J J A S O N D  55  8 2  41  8 2  42 ...
# 1                                                   J
# 2                                             55  8 2
# 3            Average max. and min. temperatures in °C
# 4                          Precipitation totals in mm
# 5   Imperial conversion JFMAMJJASOND  2.2  47 36  ...
# 6                                 Imperial conversion
# 7                                                   J
# 8                                          2.2  47 36
# 9            Average max. and min. temperatures in °F
# 10                     Precipitation totals in inches
#
#                           Unnamed: 1_level_0  \
#                           Unnamed: 1_level_1
# 0                                        NaN
# 1                                          F
# 2                                    41  8 2
# ...

# %%
d.iloc[0:7]
# Out:
#                                               London  \
# 0                                       Capital city
# 1  Clockwise from top: City of London in the fore...
# 2  .mw-parser-output .locmap .od{position:absolut...
# 3  Coordinates: .mw-parser-output .geo-default,.m...
# 4                                    Sovereign state
# 5                                            Country
# 6                                             Region
#
#                                             London.1
# 0                                       Capital city
# 1  Clockwise from top: City of London in the fore...
# 2  .mw-parser-output .locmap .od{position:absolut...
# 3  Coordinates: .mw-parser-output .geo-default,.m...
# 4                                     United Kingdom
# 5                                            England
# 6                               London (coterminous)
